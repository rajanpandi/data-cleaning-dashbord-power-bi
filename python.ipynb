# %% [markdown]
# <a href="https://colab.research.google.com/github/rajanpandi/data-cleaning-dashbord-power-bi/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import pandas as pd

# %%
customer=pd.read_csv("/content/drive/MyDrive/project_2_file/2_Customers_2.csv",encoding='ISO-8859-1')
customer
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
customer.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customer.fillna("NUL",inplace=True)

# %%
customer.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
customer.duplicated().sum()
# Out:
# 0

# %%
customer.to_csv(r"/content/customer_after cleaning.csv")

# %%
df1_customer=pd.read_csv("/content/customer_after cleaning.csv")

# %%
df2_sales=pd.read_csv("/content/sales_after cleaning.csv")

# %%
merged_data_customer_sales=pd.merge(df1_customer,df2_sales,on="CustomerKey")
merged_data_customer_sales.head()
# Out:
#    Unnamed: 0_x  CustomerKey  Gender           Name            City  \
# 0             0          301  Female  Lilly Harding  WANDEARAH EAST
# 1             1          325  Female   Madison Hull      MOUNT BUDD
# 2             1          325  Female   Madison Hull      MOUNT BUDD
# 3             1          325  Female   Madison Hull      MOUNT BUDD
# 4             1          325  Female   Madison Hull      MOUNT BUDD
#
#   State Code              State Zip Code    Country  Continent   Birthday  \
# 0         SA    South Australia     5523  Australia  Australia   7/3/1939
# 1         WA  Western Australia     6522  Australia  Australia  9/27/1979
# 2         WA  Western Australia     6522  Australia  Australia  9/27/1979
# 3         WA  Western Australia     6522  Australia  Australia  9/27/1979
# 4         WA  Western Australia     6522  Australia  Australia  9/27/1979
#
#    Unnamed: 0_y  Order Number  Line Item  Order Date  StoreKey  ProductKey  \
# ...

# %%
merged_data_customer_sales.drop(["Unnamed: 0_x", "Unnamed: 0_y"], axis=1, inplace=True)

# %%
merged_data_customer_sales
# Out:
#        CustomerKey  Gender              Name                 City State Code  \
# 0              301  Female     Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female      Madison Hull           MOUNT BUDD         WA
# 2              325  Female      Madison Hull           MOUNT BUDD         WA
# 3              325  Female      Madison Hull           MOUNT BUDD         WA
# 4              325  Female      Madison Hull           MOUNT BUDD         WA
# ...            ...     ...               ...                  ...        ...
# 62879      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62880      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62881      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62882      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62883      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
merged_data_customer_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerKey    62884 non-null  int64
#  1   Gender         62884 non-null  object
#  2   Name           62884 non-null  object
#  3   City           62884 non-null  object
#  4   State Code     62884 non-null  object
#  5   State          62884 non-null  object
#  6   Zip Code       62884 non-null  object
#  7   Country        62884 non-null  object
#  8   Continent      62884 non-null  object
#  9   Birthday       62884 non-null  object
#  10  Order Number   62884 non-null  int64
#  11  Line Item      62884 non-null  int64
#  12  Order Date     62884 non-null  object
#  13  StoreKey       62884 non-null  int64
#  14  ProductKey     62884 non-null  int64
#  15  Quantity       62884 non-null  int64
#  16  Currency Code  62884 non-null  object
# dtypes: int64(6), object(11)
# ...

# %%
merged_data_customer_sales.isnull().sum()
# Out:
# CustomerKey      0
# Gender           0
# Name             0
# City             0
# State Code       0
# State            0
# Zip Code         0
# Country          0
# Continent        0
# Birthday         0
# Order Number     0
# Line Item        0
# Order Date       0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
merged_data_customer_sales.duplicated().sum()
# Out:
# 0

# %%
merged_data_customer_sales.groupby("ProductKey")["ProductKey"].value_counts()
# Out:
# ProductKey
# 1       23
# 2       23
# 3       27
# 4       27
# 5       17
#         ..
# 2513    51
# 2514    67
# 2515    56
# 2516    43
# 2517    49
# Name: count, Length: 2492, dtype: int64

# %%
merged_data_customer_sales.to_csv(r"/content/merged_data_customer_sales.csv")

# %%
product=pd.read_csv("/content/drive/MyDrive/project_2_file/3_Products_3.csv")
product
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
product["ProductKey"].value_counts()
# Out:
# ProductKey
# 1       1
# 1683    1
# 1676    1
# 1677    1
# 1678    1
#        ..
# 840     1
# 841     1
# 842     1
# 843     1
# 2517    1
# Name: count, Length: 2517, dtype: int64

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
product.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
product.duplicated().sum()
# Out:
# 0

# %%
merged_data_customer_sales_product=pd.merge(merged_data_customer_sales,product,on="ProductKey")
merged_data_customer_sales_product
# Out:
#        CustomerKey  Gender               Name            City State Code  \
# 0              301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1            19082    Male     Matthew Denman         RANSOME        QLD
# 2            37991    Male    Cooper Gillison         CARWELL        NSW
# 3            48733  Female     Sophia Gunther        BALCOLYN        NSW
# 4            51314  Female      Bianca Stobie        DUVERNEY        VIC
# ...            ...     ...                ...             ...        ...
# 62879      1950637    Male          Roger Pon     Santa Clara         CA
# 62880      1976355    Male       Joel Mullaly          Boston         MA
# 62881      2039796    Male    Cupido Portillo      Pittsburgh         PA
# 62882      2040156    Male      Patrick Fabro    Wilkes Barre         PA
# 62883      2087477  Female  Klaudia Ebersbach     Idaho Falls         ID
#
#                  State Zip Code        Country      Continent    Birthday  \
# ...

# %%
merged_data_customer_sales_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     62884 non-null  int64
#  1   Gender          62884 non-null  object
#  2   Name            62884 non-null  object
#  3   City            62884 non-null  object
#  4   State Code      62884 non-null  object
#  5   State           62884 non-null  object
#  6   Zip Code        62884 non-null  object
#  7   Country         62884 non-null  object
#  8   Continent       62884 non-null  object
#  9   Birthday        62884 non-null  object
#  10  Order Number    62884 non-null  int64
#  11  Line Item       62884 non-null  int64
#  12  Order Date      62884 non-null  object
#  13  StoreKey        62884 non-null  int64
#  14  ProductKey      62884 non-null  int64
#  15  Quantity        62884 non-null  int64
#  16  Currency Code   62884 non-null  object
# ...

# %%
merged_data_customer_sales_product.isnull().sum()
# Out:
# CustomerKey       0
# Gender            0
# Name              0
# City              0
# State Code        0
# State             0
# Zip Code          0
# Country           0
# Continent         0
# Birthday          0
# Order Number      0
# Line Item         0
# Order Date        0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
merged_data_customer_sales_product.duplicated().sum()
# Out:
# 0

# %%
merged_data_customer_sales_product.to_csv(r"/content/merged_data_customer_sales_product.csv")

# %%
store=pd.read_csv("/content/drive/MyDrive/project_2_file/5_Stores_5.csv")
store
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
store.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
store.dropna(inplace=True)

# %%
store.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
merged_data_customer_sales_product_store=pd.merge(merged_data_customer_sales_product,store,on="StoreKey")
merged_data_customer_sales_product_store.head(5)
# Out:
#    CustomerKey  Gender            Name        City State Code  \
# 0        19082    Male  Matthew Denman     RANSOME        QLD
# 1        48733  Female  Sophia Gunther    BALCOLYN        NSW
# 2          325  Female    Madison Hull  MOUNT BUDD         WA
# 3          325  Female    Madison Hull  MOUNT BUDD         WA
# 4          325  Female    Madison Hull  MOUNT BUDD         WA
#
#              State_x Zip Code  Country_x  Continent   Birthday  ...  \
# 0         Queensland     4154  Australia  Australia   4/6/1939  ...
# 1    New South Wales     2264  Australia  Australia  7/22/1989  ...
# 2  Western Australia     6522  Australia  Australia  9/27/1979  ...
# 3  Western Australia     6522  Australia  Australia  9/27/1979  ...
# 4  Western Australia     6522  Australia  Australia  9/27/1979  ...
#
#    Unit Cost USD  Unit Price USD SubcategoryKey               Subcategory  \
# 0        $98.07         $296.00             104             Recording Pen
# ...

# %%
merged_data_customer_sales_product_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49719 entries, 0 to 49718
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     49719 non-null  int64
#  1   Gender          49719 non-null  object
#  2   Name            49719 non-null  object
#  3   City            49719 non-null  object
#  4   State Code      49719 non-null  object
#  5   State_x         49719 non-null  object
#  6   Zip Code        49719 non-null  object
#  7   Country_x       49719 non-null  object
#  8   Continent       49719 non-null  object
#  9   Birthday        49719 non-null  object
#  10  Order Number    49719 non-null  int64
#  11  Line Item       49719 non-null  int64
#  12  Order Date      49719 non-null  object
#  13  StoreKey        49719 non-null  int64
#  14  ProductKey      49719 non-null  int64
#  15  Quantity        49719 non-null  int64
#  16  Currency Code   49719 non-null  object
# ...

# %%
merged_data_customer_sales_product_store=merged_data_customer_sales_product_store.rename(columns={
    'State_x': 'customer_state',
    'Country_x': 'customer_country',
    'Country_y': 'store_country',
    'State_y': 'store_state'})
merged_data_customer_sales_product_store.head(5)
# Out:
#    CustomerKey  Gender            Name        City State Code  \
# 0        19082    Male  Matthew Denman     RANSOME        QLD
# 1        48733  Female  Sophia Gunther    BALCOLYN        NSW
# 2          325  Female    Madison Hull  MOUNT BUDD         WA
# 3          325  Female    Madison Hull  MOUNT BUDD         WA
# 4          325  Female    Madison Hull  MOUNT BUDD         WA
#
#       customer_state Zip Code customer_country  Continent   Birthday  ...  \
# 0         Queensland     4154        Australia  Australia   4/6/1939  ...
# 1    New South Wales     2264        Australia  Australia  7/22/1989  ...
# 2  Western Australia     6522        Australia  Australia  9/27/1979  ...
# 3  Western Australia     6522        Australia  Australia  9/27/1979  ...
# 4  Western Australia     6522        Australia  Australia  9/27/1979  ...
#
#    Unit Cost USD  Unit Price USD SubcategoryKey               Subcategory  \
# ...

# %%
merged_data_customer_sales_product_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49719 entries, 0 to 49718
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerKey       49719 non-null  int64
#  1   Gender            49719 non-null  object
#  2   Name              49719 non-null  object
#  3   City              49719 non-null  object
#  4   State Code        49719 non-null  object
#  5   customer_state    49719 non-null  object
#  6   Zip Code          49719 non-null  object
#  7   customer_country  49719 non-null  object
#  8   Continent         49719 non-null  object
#  9   Birthday          49719 non-null  object
#  10  Order Number      49719 non-null  int64
#  11  Line Item         49719 non-null  int64
#  12  Order Date        49719 non-null  object
#  13  StoreKey          49719 non-null  int64
#  14  ProductKey        49719 non-null  int64
#  15  Quantity          49719 non-null  int64
# ...

# %%
merged_data_customer_sales_product_store.isnull().sum()
# Out:
# CustomerKey         0
# Gender              0
# Name                0
# City                0
# State Code          0
# customer_state      0
# Zip Code            0
# customer_country    0
# Continent           0
# Birthday            0
# Order Number        0
# Line Item           0
# Order Date          0
# StoreKey            0
# ProductKey          0
# Quantity            0
# Currency Code       0
# Product Name        0
# Brand               0
# Color               0
# Unit Cost USD       0
# Unit Price USD      0
# SubcategoryKey      0
# Subcategory         0
# CategoryKey         0
# Category            0
# store_country       0
# store_state         0
# Square Meters       0
# Open Date           0
# dtype: int64

# %%
merged_data_customer_sales_product_store.duplicated().sum()
# Out:
# 0

# %%
merged_data_customer_sales_product_store.to_csv(r"/content/merged_data_customer_sales_product_store.csv")

# %%
exchange=pd.read_csv("/content/drive/MyDrive/project_2_file/4_Exchange_Rates4.csv")
exchange
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
exchange.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exchange.duplicated().sum()
# Out:
# 0

# %%
# Concatenate side by side (along columns)
joined_data = pd.concat([merged_data_customer_sales_product_store, exchange], axis=1)

# Display the first 5 rows to verify
joined_data
# Out:
#        CustomerKey  Gender               Name         City State Code  \
# 0            19082    Male     Matthew Denman      RANSOME        QLD
# 1            48733  Female     Sophia Gunther     BALCOLYN        NSW
# 2              325  Female       Madison Hull   MOUNT BUDD         WA
# 3              325  Female       Madison Hull   MOUNT BUDD         WA
# 4              325  Female       Madison Hull   MOUNT BUDD         WA
# ...            ...     ...                ...          ...        ...
# 49714       105647  Female        Anna Komine      REDWOOD        QLD
# 49715       129318  Female  Victoria Courtney  PINE VALLEY        NSW
# 49716       129318  Female  Victoria Courtney  PINE VALLEY        NSW
# 49717       129494  Female        Amber Parry    Greenwood        QLD
# 49718       129494  Female        Amber Parry    Greenwood        QLD
#
#           customer_state Zip Code customer_country  Continent   Birthday  ...  \
# ...

# %%
joined_data.isnull().sum()
# Out:
# CustomerKey             0
# Gender                  0
# Name                    0
# City                    0
# State Code              0
# customer_state          0
# Zip Code                0
# customer_country        0
# Continent               0
# Birthday                0
# Order Number            0
# Line Item               0
# Order Date              0
# StoreKey                0
# ProductKey              0
# Quantity                0
# Currency Code           0
# Product Name            0
# Brand                   0
# Color                   0
# Unit Cost USD           0
# Unit Price USD          0
# SubcategoryKey          0
# Subcategory             0
# CategoryKey             0
# Category                0
# store_country           0
# store_state             0
# Square Meters           0
# Open Date               0
# Date                38504
# Currency            38504
# Exchange            38504
# dtype: int64

# %%
joined_data.duplicated().sum()
# Out:
# 0

# %%
joined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49719 entries, 0 to 49718
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerKey       49719 non-null  int64
#  1   Gender            49719 non-null  object
#  2   Name              49719 non-null  object
#  3   City              49719 non-null  object
#  4   State Code        49719 non-null  object
#  5   customer_state    49719 non-null  object
#  6   Zip Code          49719 non-null  object
#  7   customer_country  49719 non-null  object
#  8   Continent         49719 non-null  object
#  9   Birthday          49719 non-null  object
#  10  Order Number      49719 non-null  int64
#  11  Line Item         49719 non-null  int64
#  12  Order Date        49719 non-null  object
#  13  StoreKey          49719 non-null  int64
#  14  ProductKey        49719 non-null  int64
#  15  Quantity          49719 non-null  int64
# ...

# %%
joined_data.to_csv(r"/content/joined_data.csv")

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/joined_data.csv")
df
# Out:
# <ipython-input-58-6f0420bec292>:1: DtypeWarning: Columns (7,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/joined_data.csv")
#        Unnamed: 0  CustomerKey  Gender               Name         City  \
# 0               0        19082    Male     Matthew Denman      RANSOME
# 1               1        48733  Female     Sophia Gunther     BALCOLYN
# 2               2          325  Female       Madison Hull   MOUNT BUDD
# 3               3          325  Female       Madison Hull   MOUNT BUDD
# 4               4          325  Female       Madison Hull   MOUNT BUDD
# ...           ...          ...     ...                ...          ...
# 49714       49714       105647  Female        Anna Komine      REDWOOD
# 49715       49715       129318  Female  Victoria Courtney  PINE VALLEY
# 49716       49716       129318  Female  Victoria Courtney  PINE VALLEY
# 49717       49717       129494  Female        Amber Parry    Greenwood
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# CustomerKey             0
# Gender                  0
# Name                    0
# City                    0
# State Code              0
# customer_state          0
# Zip Code                0
# customer_country        0
# Continent               0
# Birthday                0
# Order Number            0
# Line Item               0
# Order Date              0
# StoreKey                0
# ProductKey              0
# Quantity                0
# Currency Code           0
# Product Name            0
# Brand                   0
# Color                   0
# Unit Cost USD           0
# Unit Price USD          0
# SubcategoryKey          0
# Subcategory             0
# CategoryKey             0
# Category                0
# store_country           0
# store_state             0
# Square Meters           0
# Open Date               0
# Date                38504
# Currency            38504
# Exchange            38504
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[:,["Date","Currency","Exchange"]]
# Out:
#            Date Currency  Exchange
# 0      1/1/2015      USD    1.0000
# 1      1/1/2015      CAD    1.1583
# 2      1/1/2015      AUD    1.2214
# 3      1/1/2015      EUR    0.8237
# 4      1/1/2015      GBP    0.6415
# ...         ...      ...       ...
# 49714       NaN      NaN       NaN
# 49715       NaN      NaN       NaN
# 49716       NaN      NaN       NaN
# 49717       NaN      NaN       NaN
# 49718       NaN      NaN       NaN
#
# [49719 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49719 entries, 0 to 49718
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        49719 non-null  int64
#  1   CustomerKey       49719 non-null  int64
#  2   Gender            49719 non-null  object
#  3   Name              49719 non-null  object
#  4   City              49719 non-null  object
#  5   State Code        49719 non-null  object
#  6   customer_state    49719 non-null  object
#  7   Zip Code          49719 non-null  object
#  8   customer_country  49719 non-null  object
#  9   Continent         49719 non-null  object
#  10  Birthday          49719 non-null  object
#  11  Order Number      49719 non-null  int64
#  12  Line Item         49719 non-null  int64
#  13  Order Date        49719 non-null  object
#  14  StoreKey          49719 non-null  int64
#  15  ProductKey        49719 non-null  int64
# ...

# %%
columns_to_convert = ["Birthday", "Open Date", "Date"]
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_datetime)

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
column=df.columns
column
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'customer_state',
#        'Zip Code', 'customer_country', 'Continent', 'Birthday', 'Order Number',
#        'Line Item', 'Order Date', 'StoreKey', 'ProductKey', 'Quantity',
#        'Currency Code', 'Product Name', 'Brand', 'Color', 'Unit Cost USD',
#        'Unit Price USD', 'SubcategoryKey', 'Subcategory', 'CategoryKey',
#        'Category', 'store_country', 'store_state', 'Square Meters',
#        'Open Date', 'Date', 'Currency', 'Exchange'],
#       dtype='object')

# %%
df
# Out:
#        CustomerKey  Gender               Name         City State Code  \
# 0            19082    Male     Matthew Denman      RANSOME        QLD
# 1            48733  Female     Sophia Gunther     BALCOLYN        NSW
# 2              325  Female       Madison Hull   MOUNT BUDD         WA
# 3              325  Female       Madison Hull   MOUNT BUDD         WA
# 4              325  Female       Madison Hull   MOUNT BUDD         WA
# ...            ...     ...                ...          ...        ...
# 49714       105647  Female        Anna Komine      REDWOOD        QLD
# 49715       129318  Female  Victoria Courtney  PINE VALLEY        NSW
# 49716       129318  Female  Victoria Courtney  PINE VALLEY        NSW
# 49717       129494  Female        Amber Parry    Greenwood        QLD
# 49718       129494  Female        Amber Parry    Greenwood        QLD
#
#           customer_state Zip Code customer_country  Continent   Birthday  ...  \
# ...

# %%
df.to_csv(r"/content/join_data_after_cleaning.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
column=df.columns
column
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'customer_state',
#        'Zip Code', 'customer_country', 'Continent', 'Birthday', 'Order Number',
#        'Line Item', 'Order Date', 'StoreKey', 'ProductKey', 'Quantity',
#        'Currency Code', 'Product Name', 'Brand', 'Color', 'Unit Cost USD',
#        'Unit Price USD', 'SubcategoryKey', 'Subcategory', 'CategoryKey',
#        'Category', 'store_country', 'store_state', 'Square Meters',
#        'Open Date', 'Date', 'Currency', 'Exchange'],
#       dtype='object')

# %%
for i in column:
  if df[i].dtype=='int':
    x=i
    sns.boxplot(df[x])
    plt.show()

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 64.8 MB/s eta 0:00:00
# ...

# %%
#import pandas as pd
#from sqlalchemy import create_engine

# Read CSV file with dtype handling
#df = pd.read_csv('/content/join_data_after_cleaning.csv', low_memory=False)

# Define MySQL connection parameters
#user = 'root'
#password = 'Chahit@04'
#host = 'DESKTOP-MRJESOM'
#port = '3306'
#database = 'project'

# Create engine
#engine = create_engine(f'mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}')

# Write DataFrame to MySQL
#df.to_sql('your_table_name', con=engine, if_exists='replace', index=False)

# %%
import mysql.connector
server=mysql.connector.connect(host='db.c92ayia40zri.ap-south-1.rds.amazonaws.com',user='admin',password='Chahitrajan')
server
raj=server.cursor()
raj.execute('show databases')
for i in raj:
    print(i)
# Out:
# ('aws',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
import sqlalchemy

# %%
engine1=sqlalchemy.create_engine("mysql+mysqlconnector://admin:Chahitrajan@db.c92ayia40zri.ap-south-1.rds.amazonaws.com:3306/aws")

# %%
df.to_sql('join_all_data',engine1)
# Out:
# 49719
